# %% [markdown]
# In order to execute the codes below, follow these steps:
# * Be in a fresh working directory where you want to clone the dataset to
# * "brew install datalad"
# * "datalad clone https://openneuro.org/datasets/ds004636/versions/1.0.4"
#     This clones all metadata we will need to get the mriqc quality scans from ds004636/derivatives/mriqc.
# * Start this notebook at the base directory of the dataset.
#
# Notes
# - This notebook assumes the existence of a "suggested_exclusions.csv" at the base directory.
# - This notebook is specific to acquiring the dataset ds004636 only, changes are needed to accomodate other datasets.
# - Because of the (hidden) .git/ and .datalad/ directories, you won't ba able to push downloaded scans to a remote github repo because datalad uses git-annex to store the content of each file in a separate location. Git-annex stores only symbolic links that point to the actual location of content of files, but these are not pushed to github repo due to their large sizes.

# %%
'''Get suggested_exclusions.csv'''
import pandas as pd
import os
import subprocess

# suggested exclusions file from ds004636 openneuro, first column="scan_id"
csv_path = "metadata/suggested_exclusions.csv"
df = pd.read_csv(csv_path)
df.columns = ["scan_id", "MRIQC_fail"]

# Directories
mriqc_failed_dir = "metadata/mriqc_failed/"
mriqc_passed_dir = "metadata/mriqc_passed/"

os.makedirs(mriqc_failed_dir, exist_ok=True)
os.makedirs(mriqc_passed_dir, exist_ok=True)

# %%
def get_html_filename(scan_id):
    """Convert scan_id to dataset's HTML filename format."""

    parts = scan_id.split("_")
    subject = parts[0]
    task = parts[1]
    
    # Construct filename
    # this assumes all html file names include "ses-1 (session 1)"
    # we correct for "ses-2" later in code
    return f"sub-{subject}_ses-1_task-{task}_run-1_bold.html"

# %%
'''get failed_scans and passed_scans dataframes from suggested_exclusions'''

failed_files,passed_files = [],[]

# get all the scan_id's of files with mriqc_fail == 1.0 and mriqc_fail==0
failed_scans = df[df["MRIQC_fail"]==1.0]["scan_id"]
passed_scans = df[df["MRIQC_fail"]==0.0]["scan_id"]

# Save these files to mriqc_failed.txt 
short_fail_txt=mriqc_failed_dir+"mriqc_failed.txt"
long_fail_txt=mriqc_failed_dir+"mriqc_failed_fullname.txt"
short_pass_txt=mriqc_passed_dir+"mriqc_passed.txt"
long_pass_txt=mriqc_passed_dir+"mriqc_passed_fullname.txt"

# %%
'''write to short,long,failed,passed text files names of scans'''
with open((short_fail_txt), "w") as f:
    for file in failed_scans:
        f.write(file + "\n")

with open((short_pass_txt), "w") as f:
    for file in passed_scans:
        f.write(file + "\n")

with open((long_fail_txt), "w") as f:
    for file in failed_scans:
        full_name=get_html_filename(file)

        if os.path.islink(full_name):
            f.write(full_name + "\n")
        else:
            fule_name = full_name.replace("ses-1", "ses-2")
            if os.path.islink(full_name):
                f.write(full_name + "\n")
            else:
                fule_name = full_name.replace("ses-2", "ses-3")
                if os.path.islink(full_name):
                    f.write(full_name + "\n")

with open((long_pass_txt), "w") as f:
    for file in passed_scans:
        full_name=get_html_filename(file)
        if os.path.islink(full_name):
            f.write(full_name + "\n")
        else:
            fule_name = full_name.replace("ses-1", "ses-2")
            if os.path.islink(full_name):
                f.write(full_name + "\n")

# %%
'''datalad get all failed and passed scans'''
# THIS CODE GETS ALL THE FILES IN mriqc_failed.txt USING DATALAD
# WE DON'T NEED TO RUN IT AGAIN IF YOU HAVE FILES
# IT WON'T WORK IF YOU HAVEN'T CLONED THE OPENNEURO DATASET (STATED ABOVE)

filenames=[long_fail_txt,long_pass_txt]

for name in filenames:
    with open(name,"r") as f:
        for line in f:
            line=line.strip()
            filename = get_html_filename(line)
            dataset_path = f"ds004636/derivatives/mriqc/{filename}"

            try:
                subprocess.run(["/opt/homebrew/bin/datalad", "get", "-d", "ds004636", dataset_path], check=True)

            except subprocess.CalledProcessError:
                print(f"Failed to download: {filename}")

# %%
# adding newly add
